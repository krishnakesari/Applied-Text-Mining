# %%
text1 = "You have sentences or strings and they are formed of words or tokens, and words are formed out of characters. On the other side, you have documents and larger files and we're talking about all these constructs and their properties. "
len(text1)
# Out:
# 232

# %%
text2 = text1.split(' ')
len(text2)
# Out:
# 41

# %%
text1 = "You have sentences or strings and they are formed of words or tokens, and words are formed out of characters. On the other side, you have documents and larger files and we're talking about all these constructs and their properties. "
len(text1)

# Splitting Sentence
text2 = text1.split(' ')
len(text2)
# Out:
# 41

# %%
# Words longer than 3 letters
[w for w in text2 if len(w) > 3]
# Out:
# ['have',
#  'sentences',
#  'strings',
#  'they',
#  'formed',
#  'words',
#  'tokens,',
#  'words',
#  'formed',
#  'characters.',
#  'other',
#  'side,',
#  'have',
#  'documents',
#  'larger',
#  'files',
#  "we're",
#  'talking',
#  'about',
#  'these',
#  'constructs',
#  'their',
#  'properties.']

# %%
# Finding Capitalized words 
[w for w in text2 if w.istitle()]
# Out:
# ['You', 'On']

# %%
# Finding words ends with s
[w for w in text2 if w.endswith('s')]
# Out:
# ['sentences', 'strings', 'words', 'words', 'documents', 'files', 'constructs']

# %%
# Finding Unique words
len(set(text2))
# Out:
# 31

# %%
# Split at 'ou'
text5 = "ouagadougou"
text6 = text5.split('ou')
text6
# Out:
# ['', 'agad', 'g', '']

# %%
# Join at 'ou'
'ou'.join(text6)
# Out:
# 'ouagadougou'

# %%
# Getting characters from words
[c for c in text5]
# Out:
# ['o', 'u', 'a', 'g', 'a', 'd', 'o', 'u', 'g', 'o', 'u']
